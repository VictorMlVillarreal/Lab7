# %%
import folium
from branca.element import Figure

my_map = folium.Map(location=(10.509643750389012, -83.91913210756003))

popuptext='<b>Campus Omar Dengo'
folium.Marker(location = [9.998927052587783, -84.1114826924263],popup=popuptext,icon=folium.Icon(color = "orange",icon="ok,sin")).add_to(my_map)
folium.Circle(location=[9.998927052587783, -84.1114826924263], color = "purple", weight = 6,fill_color="red", fill_opacity=0.5,tooltip="Campus Omar Dengo").add_to(my_map)

popuptext1='<b>Campus Interuniversitaria (Alajuela)'
folium.Marker(location = [10.019987424361195, -84.1970253327662],popup=popuptext1,icon=folium.Icon(color = "orange",icon="ok,sin")).add_to(my_map)
folium.Circle(location=[10.019987424361195, -84.1970253327662], color = "purple", weight = 6,fill_color="red", fill_opacity=0.5,tooltip="Campus Interuniversitaria (Alajuela)").add_to(my_map)

popuptext2='<b>Campus Liberia)'
folium.Marker(location = [10.61770519022363, -85.45144172768667],popup=popuptext2,icon=folium.Icon(color = "orange",icon="ok,sin")).add_to(my_map)
folium.Circle(location=[10.61770519022363, -85.45144172768667], color = "purple", weight = 6,fill_color="red", fill_opacity=0.5,tooltip="Campus Liberia").add_to(my_map)

popuptext3='<b>Campus Nicoya)'
folium.Marker(location = [10.1346496342429, -85.44677311927003],popup=popuptext3,icon=folium.Icon(color = "orange",icon="ok,sin")).add_to(my_map)
folium.Circle(location=[10.1346496342429, -85.44677311927003], color = "purple", weight = 6,fill_color="red", fill_opacity=0.5,tooltip="Campus Nicoya").add_to(my_map)

popuptext4='<b>Campus Pérez Zeledón)'
folium.Marker(location = [9.379763144493369, -83.69152724155619],popup=popuptext4,icon=folium.Icon(color = "orange",icon="ok,sin")).add_to(my_map)
folium.Circle(location=[9.379763144493369, -83.69152724155619], color = "purple", weight = 6,fill_color="red", fill_opacity=0.5,tooltip="Campus Pérez Zeledón").add_to(my_map)

popuptext5='<b>Campus Coto)'
folium.Marker(location = [8.57352484358814, -82.87243460394026],popup=popuptext5,icon=folium.Icon(color = "orange",icon="ok,sin")).add_to(my_map)
folium.Circle(location=[8.57352484358814, -82.87243460394026], color = "purple", weight = 6,fill_color="red", fill_opacity=0.5,tooltip="Campus Coto").add_to(my_map)

popuptext6='<b>Campus Benjamin Nuñez'
folium.Marker(location = [9.97104416647061, -84.12839139619396],popup=popuptext6,icon=folium.Icon(color = "orange",icon="ok,sin")).add_to(my_map)
folium.Circle(location=[9.97104416647061, -84.12839139619396], color = "purple", weight = 6,fill_color="red", fill_opacity=0.5,tooltip="Campus Benjamin Nuñez").add_to(my_map)

popuptext6='<b>Campus Sarapiqui'
folium.Marker(location = [10.319317760135103, -83.92273488814693],popup=popuptext6,icon=folium.Icon(color = "orange",icon="ok,sin")).add_to(my_map)
folium.Circle(location=[10.319317760135103, -83.92273488814693], color = "purple", weight = 6,fill_color="red", fill_opacity=0.5,tooltip="Campus Sarapiqui").add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
